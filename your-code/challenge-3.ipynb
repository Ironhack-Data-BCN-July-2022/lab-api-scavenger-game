# %% [markdown]
# # Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
#
# After you find out the secrete files:
#
# Sort the filenames ascendingly.
#
# Read the content of each secret files into an array of strings.
#
# Concatenate the strings in the array separating each two with a whitespace.
#
# Print out the joke.

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
# Your code

# %%
# Example: print(variable[:10])

# %%
import json
import requests
import pandas as pd
from pandas import json_normalize

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
github = os.getenv("token")

# %%
parameters = {"Authorization":f"token {github}"}

# %%
url = "https://api.github.com/repos/ironhack-datalabs/scavenger/commits"
url
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/scavenger/commits'

# %%
requests.get(url, parameters)
# Out:
# <Response [200]>

# %%
res = requests.get(url, parameters)
scavanger = res.json()

# %%
scavanger

# in this part we are trying to find the repository tree
# with this information we can see the files in the repository
# 'tree': {'sha': '0d82bf748275dbc1239a11e9157b198d88da7383',
#'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383'},

# the API URL that we need will list all files, 
#now we need to access said files.
# Out:
# [{'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'node_id': 'MDY6Q29tbWl0MTYyMzc1MTgxOjkzMDhjY2M4YTRjMzRjNWUzYTk5MWVlODE1MjIyYTk2OTFjMzI0NzY=',
#   'commit': {'author': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2018-12-19T03:03:57Z'},
#    'committer': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2018-12-19T03:03:57Z'},
#    'message': 'initial commit',
#    'tree': {'sha': '0d82bf748275dbc1239a11e9157b198d88da7383',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
json_normalize(scavanger)
# Out:
#                                         sha  \
# 0  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MTYyMzc1MTgxOjkzMDhjY2M4YTRjMzRjNW...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/scavenger...
#
#                                         comments_url parents  \
# 0  https://api.github.com/repos/ironhack-datalabs...      []
#
#   commit.author.name  commit.author.email    commit.author.date  \
# 0          Zhou Zhou  zhou.eye8@gmail.com  2018-12-19T03:03:57Z
#
#   commit.committer.name  ...  \
# 0             Zhou Zhou  ...
#
#                              committer.following_url  \
# 0  https://api.github.com/users/eye8/following{/o...
#
#                                  committer.gists_url  \
# ...

# %% [markdown]
# # Accesing the Scavanger trees

# %%
url2 = "https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383"
url2
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383'

# %%
tree = requests.get(url2, parameters)
scavanger2 = [tree.json()]

# %%
scavanger2
# Out:
# [{'sha': '0d82bf748275dbc1239a11e9157b198d88da7383',
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383',
#   'tree': [{'path': '.gitignore',
#     'mode': '100644',
#     'type': 'blob',
#     'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#     'size': 10,
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#    {'path': '15024',
#     'mode': '040000',
#     'type': 'tree',
#     'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#    {'path': '15534',
#     'mode': '040000',
#     'type': 'tree',
#     'sha': '5af6f2a7287e4191f39e55693fc1e9c8918d1d3a',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a'},
#    {'path': '17020',
# ...

# %%
scavanger2["tree"][0]["url"]
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'

# %%
scavanger2[0]
# Out:
# {'sha': '0d82bf748275dbc1239a11e9157b198d88da7383',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383',
#  'tree': [{'path': '.gitignore',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'size': 10,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#   {'path': '15024',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#   {'path': '15534',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '5af6f2a7287e4191f39e55693fc1e9c8918d1d3a',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a'},
#   {'path': '17020',
#    'mode': '040000',
# ...

# %%
range(len(scavanger2["tree"])-1):
# Out:
# 25

# %%
file_url = []

for i in range(len(scavanger2["tree"])-1):
    url_file = scavanger2["tree"][i]["url"]
    file_url.append(url_file)
print(file_url)

#this code is extracting the URL of all the the files 
#and save them to a list
# Out:
# ['https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9c49f920aa4d9433fa99a5824128f0e6b90ec5f2', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/c488d7f64088c852e22067d48fdc64ee3670f3ba', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/30193d9cf62b07bcbb6366513ff03596861f2d29', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/22fc3d5c2db80822c351edb2248f3491c8ebda86', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/6a4a88cd9084110c8646c3cfd84dfe96b300a4a7', 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/c7001604cdadc2fe7b82e0f6996690718cac6941'
# ...

# %%
url4="https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d"
test = requests.get(url4, parameters)

# %%
test
# Out:
# <Response [200]>

# %%
test.json()
# Out:
# {'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d',
#  'tree': [{'path': '.0006.scavengerhunt',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'},
#   {'path': '40',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#    'size': 0,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391'},
#   {'path': '74',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#    'size': 0,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391'},
#   {'path': '99',
# ...

# %%
url5="https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b"
test = requests.get(url5, parameters,)
test.json()
# Out:
# {'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#  'node_id': 'MDQ6QmxvYjE2MjM3NTE4MToxYzkwNjQyODRhMjRiMzQ4NjAxNWVhZmRiMzkxYjE0MWMyN2FkYTJi',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'content': 'b2YK\n',
#  'encoding': 'base64'}

# %%
headers = {'Accept': 'application/vnd.github.v3.raw'}

# %%
test = requests.get(url5, parameters,headers=headers)
test
# Out:
# <Response [200]>

# %%
test
# Out:
# <Response [200]>

# %% [markdown]
# # Take 2 at the problem

# %%
username = "Chelechepe"
parameters = {"Authorization":f"token {github}"}
# already creater token github and username to access the API

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
url
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'

# %%
scav_res = requests.get(url, parameters)
scav_res # calling response ot validate conection
# Out:
# <Response [200]>

# %%
scav_json = scav_res.json() #translationg and saving the text to a dict

# %%
scav_json[1]["path"] 
# check for the path that leads to files name
#followed by a loop to extract it from all the paths 
#list of dictionaries with "path" in it.
# Out:
# '15024'

# %%
file_name = []
for i in scav_json[1:]: # we put the 1 because the first file it .gitignore
    file_name.append(i["path"])
print(file_name)
# Out:
# ['15024', '15534', '17020', '30351', '40303', '44639', '45525', '47222', '47830', '49418', '50896', '55417', '55685', '60224', '64880', '66032', '68848', '70751', '70985', '88596', '89046', '89338', '91701', '97881', '98750']

# %%
len(file_name)
# Out:
# 25

# %%
content_list = []
for file in file_name:
    url2 = f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{file}'
    #this loop will access every file in the list called file_name
    #we want it to display the contents of the file
    cont_res = requests.get(url2,parameters)
    cont_json = cont_res.json()
    content_list.append(cont_json)

# %%
content_list
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
len(content_list[0][0])
# Out:
# 10

# %%
content_list[0][0]["name"] # this is showing the files name
# Out:
# '.0006.scavengerhunt'

# %%
content_list[0][0]["path"] # this is the path to take in the url path
# Out:
# '15024/.0006.scavengerhunt'

# %%
path_list=[]
for i in range(24):
    extract = content_list[i][0]["path"] 
    if extract.endswith("scavengerhunt"):
        path_list.append(extract)

# %%
len(content_list)
# Out:
# 25

# %%
path_list
# Out:
# ['15024/.0006.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '55417/.0023.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '97881/.0009.scavengerhunt']

# %%
path_list.sort(key = lambda x: x.split()[0])

# %%
path_list
# Out:
# ['15024/.0006.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '55417/.0023.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '97881/.0009.scavengerhunt']

# %%
path_list2=[]
for i in range(len(content_list)-1):
    extract = content_list[i][0]["name"] 
    if extract.endswith("scavengerhunt"):
        path_list2.append(extract)

# %%
path_list2
# Out:
# ['.0006.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0009.scavengerhunt']

# %%
pathlist = zip(path_list2, path_list)
pathlist2 = list(pathlist)
print(pathlist2)
# Out:
# [('.0006.scavengerhunt', '15024/.0006.scavengerhunt'), ('.0008.scavengerhunt', '15534/.0008.scavengerhunt'), ('.0007.scavengerhunt', '17020/.0007.scavengerhunt'), ('.0021.scavengerhunt', '30351/.0021.scavengerhunt'), ('.0022.scavengerhunt', '40303/.0022.scavengerhunt'), ('.0005.scavengerhunt', '44639/.0005.scavengerhunt'), ('.0018.scavengerhunt', '45525/.0018.scavengerhunt'), ('.0016.scavengerhunt', '47222/.0016.scavengerhunt'), ('.0010.scavengerhunt', '47830/.0010.scavengerhunt'), ('.0014.scavengerhunt', '49418/.0014.scavengerhunt'), ('.0011.scavengerhunt', '50896/.0011.scavengerhunt'), ('.0023.scavengerhunt', '55417/.0023.scavengerhunt'), ('.0020.scavengerhunt', '55685/.0020.scavengerhunt'), ('.0003.scavengerhunt', '60224/.0003.scavengerhunt'), ('.0004.scavengerhunt', '68848/.0004.scavengerhunt'), ('.0019.scavengerhunt', '70751/.0019.scavengerhunt'), ('.0017.scavengerhunt', '70985/.0017.scavengerhunt'), ('.0002.scavengerhunt', '88596/.0002.scavengerhunt'), ('.0013.scavengerhunt', '
# ...

# %%
pathlist2
# Out:
# [('.0006.scavengerhunt', '15024/.0006.scavengerhunt'),
#  ('.0008.scavengerhunt', '15534/.0008.scavengerhunt'),
#  ('.0007.scavengerhunt', '17020/.0007.scavengerhunt'),
#  ('.0021.scavengerhunt', '30351/.0021.scavengerhunt'),
#  ('.0022.scavengerhunt', '40303/.0022.scavengerhunt'),
#  ('.0005.scavengerhunt', '44639/.0005.scavengerhunt'),
#  ('.0018.scavengerhunt', '45525/.0018.scavengerhunt'),
#  ('.0016.scavengerhunt', '47222/.0016.scavengerhunt'),
#  ('.0010.scavengerhunt', '47830/.0010.scavengerhunt'),
#  ('.0014.scavengerhunt', '49418/.0014.scavengerhunt'),
#  ('.0011.scavengerhunt', '50896/.0011.scavengerhunt'),
#  ('.0023.scavengerhunt', '55417/.0023.scavengerhunt'),
#  ('.0020.scavengerhunt', '55685/.0020.scavengerhunt'),
#  ('.0003.scavengerhunt', '60224/.0003.scavengerhunt'),
#  ('.0004.scavengerhunt', '68848/.0004.scavengerhunt'),
#  ('.0019.scavengerhunt', '70751/.0019.scavengerhunt'),
#  ('.0017.scavengerhunt', '70985/.0017.scavengerhunt'),
# ...

# %%
def convert(tupple, dictionary):
    for a, b in tupple:
        dictionary.setdefault(a,[]).append(b)
    return dictionary

# %%
path_dict = {}

# %%
convert(pathlist2, path_dict)
# Out:
# {'.0006.scavengerhunt': ['15024/.0006.scavengerhunt'],
#  '.0008.scavengerhunt': ['15534/.0008.scavengerhunt'],
#  '.0007.scavengerhunt': ['17020/.0007.scavengerhunt'],
#  '.0021.scavengerhunt': ['30351/.0021.scavengerhunt'],
#  '.0022.scavengerhunt': ['40303/.0022.scavengerhunt'],
#  '.0005.scavengerhunt': ['44639/.0005.scavengerhunt'],
#  '.0018.scavengerhunt': ['45525/.0018.scavengerhunt'],
#  '.0016.scavengerhunt': ['47222/.0016.scavengerhunt'],
#  '.0010.scavengerhunt': ['47830/.0010.scavengerhunt'],
#  '.0014.scavengerhunt': ['49418/.0014.scavengerhunt'],
#  '.0011.scavengerhunt': ['50896/.0011.scavengerhunt'],
#  '.0023.scavengerhunt': ['55417/.0023.scavengerhunt'],
#  '.0020.scavengerhunt': ['55685/.0020.scavengerhunt'],
#  '.0003.scavengerhunt': ['60224/.0003.scavengerhunt'],
#  '.0004.scavengerhunt': ['68848/.0004.scavengerhunt'],
#  '.0019.scavengerhunt': ['70751/.0019.scavengerhunt'],
#  '.0017.scavengerhunt': ['70985/.0017.scavengerhunt'],
# ...

# %%
path_sort = {}
for key in sorted(path_dict):
    path_sort[key] = path_dict[key]
fpath = list(path_sort.values())
fpath
# Out:
# [['88596/.0002.scavengerhunt'],
#  ['60224/.0003.scavengerhunt'],
#  ['68848/.0004.scavengerhunt'],
#  ['44639/.0005.scavengerhunt'],
#  ['15024/.0006.scavengerhunt'],
#  ['17020/.0007.scavengerhunt'],
#  ['15534/.0008.scavengerhunt'],
#  ['97881/.0009.scavengerhunt'],
#  ['47830/.0010.scavengerhunt'],
#  ['50896/.0011.scavengerhunt'],
#  ['89338/.0013.scavengerhunt'],
#  ['49418/.0014.scavengerhunt'],
#  ['91701/.0015.scavengerhunt'],
#  ['47222/.0016.scavengerhunt'],
#  ['70985/.0017.scavengerhunt'],
#  ['45525/.0018.scavengerhunt'],
#  ['70751/.0019.scavengerhunt'],
#  ['55685/.0020.scavengerhunt'],
#  ['30351/.0021.scavengerhunt'],
#  ['40303/.0022.scavengerhunt'],
#  ['55417/.0023.scavengerhunt']]

# %%
fpath[20][0]
# Out:
# '55417/.0023.scavengerhunt'

# %%
headers = {'Accept': 'application/vnd.github.v3.raw'}
j_cont = []
for i in range(21):
    extract = fpath[i][0]
    urlf = f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{extract}'
    path_res = requests.get(urlf, auth=(username, github), headers=headers)
    j_cont.append(path_res.text)   
j_cont
# Out:
# ['data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n']

# %%
len(fpath[0][0])

# %%
thejoke= []

for i in j_cont:
    stripped = i.replace("\n", "")
    thejoke.append(stripped)
    
the_joke = " ".join(map(str, thejoke))
the_joke
# Out:
# 'data science, 80 percent of time spent is preparing data, percent of time is spent complaining about the need to prepare'
